# %%
import numpy as np
import pandas as pd
import random

# %%
df = pd.read_csv("tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['total_bill'] > 40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
bool_series = df['total_bill'] > 40

# %%
df[bool_series]
# or
df[df['total_bill'] > 40 ]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
df[df['sex'] == "Male" ]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
# AND & --- BOTH COND NEED TO BE TRUE
# OR | --- EITHER COND IS TRUE

# %%
df[(df['total_bill'] > 30) & (df['sex'] == "Male")]
# Out:
#      total_bill    tip   sex smoker   day    time  size
# 23        39.42   7.58  Male     No   Sat  Dinner     4
# 39        31.27   5.00  Male     No   Sat  Dinner     3
# 44        30.40   5.60  Male     No   Sun  Dinner     4
# 47        32.40   6.00  Male     No   Sun  Dinner     4
# 56        38.01   3.00  Male    Yes   Sat  Dinner     4
# 59        48.27   6.73  Male     No   Sat  Dinner     4
# 83        32.68   5.00  Male    Yes  Thur   Lunch     2
# 95        40.17   4.73  Male    Yes   Fri  Dinner     4
# 112       38.07   4.00  Male     No   Sun  Dinner     3
# 141       34.30   6.70  Male     No  Thur   Lunch     6
# 142       41.19   5.00  Male     No  Thur   Lunch     5
# 156       48.17   5.00  Male     No   Sun  Dinner     6
# 167       31.71   4.50  Male     No   Sun  Dinner     4
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3
# 173       31.85   3.18  Male    Yes   Sun  Dinner     2
# 175       32.90   3.11  Male    Yes   Sun  Dinner     2
# 179       34.63   3.55  Male    Yes   Sun  Dinner     2
# 180       34.65   3.68  Male    Yes   Sun  Dinner     4
# 182       45.35   3.50  Male    Yes   Sun  Dinner     3
# 184       40.55   3.00  Male    Yes   Sun  Dinner     2
# 187       30.46   2.00  Male    Yes   Sun  Dinner     5
# 207       38.73   3.00  Male    Yes   Sat  Dinner     4
# 210       30.06   2.00  Male    Yes   Sat  Dinner     3
# 212       48.33   9.00  Male     No   Sat  Dinner     4
# 237       32.83   1.17  Male    Yes   Sat  Dinner     2

# %%
df[(df['total_bill'] > 30) | (df['sex'] == "Male")]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 5         25.29  4.71    Male     No  Sun  Dinner     4
# 6          8.77  2.00    Male     No  Sun  Dinner     2
# ..          ...   ...     ...    ...  ...     ...   ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [164 rows x 7 columns]

# %%
df[(df['day']=='Sun') | (df['day']=='Sat') | (df['day']=='Fri')]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [182 rows x 7 columns]

# %%
options = ['Sat','Sun']
df[df['day'].isin(options)]
#or
df[df['day'].isin(['Sat','Sun'])]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
str(12345675634)[-4:]
# Out:
# '5634'

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(123456789)
# Out:
# '6789'

# %%
random_numbers = [random.randint(100000000, 999999999) for _ in range(len(df))]

# %%
df['CC Number'] = random_numbers

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  CC Number
# 0       16.99  1.01  Female     No  Sun  Dinner     2  109596786
# 1       10.34  1.66    Male     No  Sun  Dinner     3  561361528
# 2       21.01  3.50    Male     No  Sun  Dinner     3  787289728
# 3       23.68  3.31    Male     No  Sun  Dinner     2  345121808
# 4       24.59  3.61  Female     No  Sun  Dinner     4  688686567

# %%
df.to_csv('tips.csv', index=False)

# %%
df['CC Number'].apply(last_four)
# Out:
# 0      6786
# 1      1528
# 2      9728
# 3      1808
# 4      6567
#        ...
# 239    7986
# 240    8708
# 241    0107
# 242    8274
# 243    3137
# Name: CC Number, Length: 244, dtype: object

# %%
df['CC Number'].apply(last_four)
# Out:
# 0      6786
# 1      1528
# 2      9728
# 3      1808
# 4      6567
#        ...
# 239    7986
# 240    8708
# 241    0107
# 242    8274
# 243    3137
# Name: CC Number, Length: 244, dtype: object

# %%
df['last_four'] = df['CC Number'].apply(last_four)

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  CC Number last_four  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  109596786      6786
# 1         10.34  1.66    Male     No   Sun  Dinner     3  561361528      1528
# 2         21.01  3.50    Male     No   Sun  Dinner     3  787289728      9728
# 3         23.68  3.31    Male     No   Sun  Dinner     2  345121808      1808
# 4         24.59  3.61  Female     No   Sun  Dinner     4  688686567      6567
# ..          ...   ...     ...    ...   ...     ...   ...        ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  813527986      7986
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  323358708      8708
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  105990107      0107
# 242       17.82  1.75    Male     No   Sat  Dinner     2  929998274      8274
# 243       18.78  3.00  Female     No  Thur  Dinner     2  921523137      3137
#
#     yelp
# 0     $$
# 1     $$
# 2     $$
# 3     $$
# 4     $$
# ..   ...
# 239   $$
# 240   $$
# 241   $$
# 242   $$
# 243   $$
#
# [244 rows x 10 columns]

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['total_bill'].apply(lambda bill: bill*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
df['Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  CC Number last_four  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2  109596786      6786
# 1       10.34  1.66    Male     No  Sun  Dinner     3  561361528      1528
# 2       21.01  3.50    Male     No  Sun  Dinner     3  787289728      9728
# 3       23.68  3.31    Male     No  Sun  Dinner     2  345121808      1808
# 4       24.59  3.61  Female     No  Sun  Dinner     4  688686567      6567
#
#   yelp Quality
# 0   $$   Other
# 1   $$   Other
# 2   $$   Other
# 3   $$   Other
# 4   $$   Other

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  CC Number last_four  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2  109596786      6786
# 1       10.34  1.66    Male     No  Sun  Dinner     3  561361528      1528
# 2       21.01  3.50    Male     No  Sun  Dinner     3  787289728      9728
# 3       23.68  3.31    Male     No  Sun  Dinner     2  345121808      1808
# 4       24.59  3.61  Female     No  Sun  Dinner     4  688686567      6567
#
#   yelp Quality
# 0   $$   Other
# 1   $$   Other
# 2   $$   Other
# 3   $$   Other
# 4   $$   Other

# %%
import timeit

# %%
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"
'''

# %%
# code snippet whose execution time is to be measured 
stmt_one = '''
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])
'''

# %%
timeit.timeit(setup=setup,stmt=stmt_one,number=1000)
# Out:
# 1.5913359999999557

# %%
timeit.timeit(setup=setup,stmt=stmt_two,number=1000)
# Out:
# 0.1531129999998484
